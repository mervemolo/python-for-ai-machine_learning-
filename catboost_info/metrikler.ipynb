# %%
import pandas as pd
import numpy as np
from sklearn.metrics import mean_squared_error,r2_score
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

# %%
data = {
    'Deneyim_Yili': [1, 2, 3, 5, 7, 8, 10, 12, 15, 18],
    'Egitim_Seviyesi': [1, 1, 2, 2, 3, 3, 3, 4, 4, 4], # 1: Lisans, 2: YL, 3: Doktora...
    'Maas': [28000, 32000, 42000, 58000, 75000, 82000, 105000, 130000, 160000, 190000] # Target
}

# %%
df=pd.DataFrame(data)

# %%
df.head(3)
# Out:
#    Deneyim_Yili  Egitim_Seviyesi   Maas
# 0             1                1  28000
# 1             2                1  32000
# 2             3                2  42000

# %%
y=df["Maas"]
x=df.drop("Maas",axis=1)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=42,train_size=0.8)

# %%
rf=RandomForestClassifier()

# %%
model=rf.fit(x_train,y_train)

# %%
y_pred=model.predict(x_test)

# %%
r2=r2_score(y_test,y_pred)
rmse=np.sqrt(mean_squared_error(y_test,y_pred))
model.score(x_test,y_test)
# Out:
# 0.0

# %%
tahmin=model.predict([[0,1]])
print(tahmin)
# Out:
# [28000]
# c:\Users\Merve\Desktop\PythonProjects\python-for-ai\.venv\Lib\site-packages\sklearn\utils\validation.py:2827: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %%
r2
# Out:
# 0.88818359375

# %%
rmse
# Out:
# np.float64(21400.934559032696)

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 458000000.0
