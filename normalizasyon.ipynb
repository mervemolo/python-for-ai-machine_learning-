# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler,MinMaxScaler

# %%
df=pd.read_csv("Plane Price.csv")

# %%
df.head(3)
# Out:
#                      Model Name Engine Type HP or lbs thr ea engine  \
# 0  100 Darter (S.L. Industries)      Piston                     145
# 1                   7 CCM Champ      Piston                      85
# 2  100 Darter (S.L. Industries)      Piston                      90
#
#   Max speed Knots  Rcmnd cruise Knots  Stall Knots dirty  Fuel gal/lbs  \
# 0             104                91.0               46.0            36
# 1              89                83.0               44.0            15
# 2              90                78.0               37.0            19
#
#   All eng rate of climb  Eng out rate of climb  Takeoff over 50ft  \
# 0                   450                  900.0             1300.0
# 1                   600                  720.0              800.0
# 2                   650                  475.0              850.0
#
#   Landing over 50ft Empty weight lbs Length ft/in Wing span ft/in Range N.M.  \
# 0             2,050            1,180         25/3            37/5        370
# 1             1,350              820         20/7            36/1        190
# 2             1,300              810         21/5            35/0        210
#
#        Price
# 0  1300000.0
# 1  1230000.0
# 2  1600000.0

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 517 entries, 0 to 516
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Model Name               517 non-null    str
#  1   Engine Type              517 non-null    str
#  2   HP or lbs thr ea engine  517 non-null    str
#  3   Max speed Knots          497 non-null    str
#  4   Rcmnd cruise Knots       507 non-null    float64
#  5   Stall Knots dirty        502 non-null    float64
#  6   Fuel gal/lbs             517 non-null    int64
#  7   All eng rate of climb    513 non-null    str
#  8   Eng out rate of climb    491 non-null    float64
#  9   Takeoff over 50ft        492 non-null    float64
#  10  Landing over 50ft        517 non-null    str
#  11  Empty weight lbs         516 non-null    str
#  12  Length ft/in             517 non-null    str
#  13  Wing span ft/in          517 non-null    str
#  14  Range N.M.               499 non-null    str
#  15  Price                    507 non-null    float64
# dtypes: float64(5), int64(1), str(10)
# memory usage: 64.8 KB

# %%
df=df[["Rcmnd cruise Knots","Stall Knots dirty","Fuel gal/lbs","Eng out rate of climb","Price"]]
df=df.dropna()
df.head(3)
# Out:
#    Rcmnd cruise Knots  Stall Knots dirty  Fuel gal/lbs  Eng out rate of climb  \
# 0                91.0               46.0            36                  900.0
# 1                83.0               44.0            15                  720.0
# 2                78.0               37.0            19                  475.0
#
#        Price
# 0  1300000.0
# 1  1230000.0
# 2  1600000.0

# %%
y=df["Price"]
x=df.drop(columns=["Price"])

# %% [markdown]
# Y için normalizasyon yapılmaz.
# Outlier etkisini azaltır.
# Model performansı artar.

# %%
ss=StandardScaler()
x2=ss.fit_transform(x)

# %%
np.mean(x2)
# Out:
# np.float64(3.475480772739621e-17)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 460 entries, 0 to 516
# Data columns (total 5 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Rcmnd cruise Knots     460 non-null    float64
#  1   Stall Knots dirty      460 non-null    float64
#  2   Fuel gal/lbs           460 non-null    int64
#  3   Eng out rate of climb  460 non-null    float64
#  4   Price                  460 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 21.6 KB
